# %% [markdown]
# ## Parts of speech Tags

# %% [markdown]
# "Sun is bright!"

# %%
CC coordinating conjunction 
CD cardinal digit 
DT determiner 
EX existential there (like: “there is” … think of it like “there exists”) 
FW foreign word 
IN preposition/subordinating conjunction 
JJ adjective – ‘big’ 
JJR adjective, comparative – ‘bigger’ 
JJS adjective, superlative – ‘biggest’ 
LS list marker 1) 
MD modal – could, will 
NN noun, singular ‘- desk’ 
NNS noun plural – ‘desks’ 
NNP proper noun, singular – ‘Harrison’ 
NNPS proper noun, plural – ‘Americans’ 
PDT predeterminer – ‘all the kids’ 
POS possessive ending parent’s 
PRP personal pronoun –  I, he, she 
PRP$ possessive pronoun – my, his, hers 
RB adverb – very, silently, 
RBR adverb, comparative – better 
RBS adverb, superlative – best 
RP particle – give up 
TO – to go ‘to’ the store. 
UH interjection – errrrrrrrm 
VB verb, base form – take 
VBD verb, past tense – took 
VBG verb, gerund/present participle – taking 
VBN verb, past participle – taken 
VBP verb, sing. present, non-3d – take 
VBZ verb, 3rd person sing. present – takes 
WDT wh-determiner – which 
WP wh-pronoun – who, what 
WP$ possessive wh-pronoun, eg- whose 
WRB wh-adverb, eg- where, when

# %%
paragraph="""Konidela Pawan Kalyan[5] (born Konidela Kalyan Babu;[8] 2 September 1971)[2] is an Indian politician, actor, philanthropist, and martial artist serving as the 11th Deputy Chief Minister of Andhra Pradesh since June 2024. He is also the Minister of Panchayat Raj, Rural Development and Rural Water Supply; Environment, Forest, Science and Technology in the Government of Andhra Pradesh as MLA representing the Pithapuram constituency.[3] He is the founder and president of the Janasena Party.

As an actor, Kalyan is known for his distinctive style and mannerisms in Telugu cinema. He enjoys a huge fanbase across the Telugu states, often described as "unfathomable," "fiercely loyal," and akin to a "cult following."[12] He is among the highest-paid actors in Indian cinema and has been featured in Forbes India's Celebrity 100 list multiple times since 2012.[13][18] He is the recipient of a Filmfare Award and a SIIMA Award among other accolades.

Kalyan made his acting debut in the 1996 film Akkada Ammayi Ikkada Abbayi. Then, he had a streak of six consecutive hits, among which Tholi Prema (1998), Thammudu (1999), Badri (2000), and Kushi (2001) became back-to-back blockbusters. These films established Kalyan as a youth icon with a massive following distinct from his elder brother Chiranjeevi's fanbase.[9][11] In 2001, he became the first ever South Indian brand ambassador for Pepsi.[22] Kalyan later faced a slump, yet his popularity kept soaring despite the flops.[24] He made a comeback with Jalsa (2008), the highest-grossing Telugu film of that year, and continued with hits like Gabbar Singh (2012), Attarintiki Daredi (2013), Gopala Gopala (2015), and Bheemla Nayak (2022). He received the Filmfare Award for Best Actor for Gabbar Singh. Both Kushi and Attarintiki Daredi held the record for the highest-grossing Telugu film of its era.[25]

Kalyan holds a black belt in Karate.[26] In 1997, he was awarded the title "Pawan" by the Isshin-ryū Karate Association after a public martial arts demonstration.[27] He practices various martial arts, which he regularly showcases in his films both as a performer and an action choreographer. He is known as the "Power Star" among his fans and the media.[28] Kalyan is also recognized for his extensive philanthropic work, supporting various social causes.[29] He has offered financial assistance to both individuals and organizations in need. In 2007, he established the charity Common Man Protection Force.[32]"""

# %%
import nltk

# %%
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['Konidela Pawan Kalyan[5] (born Konidela Kalyan Babu;[8] 2 September 1971)[2] is an Indian politician, actor, philanthropist, and martial artist serving as the 11th Deputy Chief Minister of Andhra Pradesh since June 2024.',
#  'He is also the Minister of Panchayat Raj, Rural Development and Rural Water Supply; Environment, Forest, Science and Technology in the Government of Andhra Pradesh as MLA representing the Pithapuram constituency.',
#  '[3] He is the founder and president of the Janasena Party.',
#  'As an actor, Kalyan is known for his distinctive style and mannerisms in Telugu cinema.',
#  'He enjoys a huge fanbase across the Telugu states, often described as "unfathomable," "fiercely loyal," and akin to a "cult following.',
#  '"[12] He is among the highest-paid actors in Indian cinema and has been featured in Forbes India\'s Celebrity 100 list multiple times since 2012.',
#  '[13][18] He is the recipient of a Filmfare Award and a SIIMA Award among other accolades.',
#  'Kalyan made his acting debut in the 1996 film Akkada Ammayi Ikkada Abbayi.',
#  'Then, he had a streak of six consecutive hits, among which Tholi Prema (1998), Thammudu (1999), Badri (2000), and Kushi (2001) became back-to-back blockbusters.',
#  "These films established Kalyan as a youth icon with a massive following distinct from his elder brother Chiranjeevi's fanbase.",
#  '[9][11] In 2001, he became the first ever South Indian brand ambassador for Pepsi.',
#  '[22] Kalyan later faced a slump, yet his popularity kept soaring despite the flops.',
#  '[24] He made a comeback with Jalsa (2008), the highest-grossing Telugu film of that year, and continued with hits like Gabbar Singh (2012), Attarintiki Daredi (2013), Gopala Gopala (2015), and Bheemla Nayak (2022).',
#  'He received the Filmfare Award for Best Actor for Gabbar Singh.',
#  'Both Kushi and Attarintiki Daredi held the record for the highest-grossing Telugu film of its era.',
#  '[25]\n\nKalyan holds a black belt in Karate.',
#  '[26] In 1997, he was awarded the title "Pawan" by the Isshin-ryū Karate Association after a public martial arts demonstration.',
#  '[27] He practices various martial arts, which he regularly showcases in his films both as a performer and an action choreographer.',
#  'He is known as the "Power Star" among his fans and the media.',
#  '[28] Kalyan is also recognized for his extensive philanthropic work, supporting various social causes.',
#  '[29] He has offered financial assistance to both individuals and organizations in need.',
#  'In 2007, he established the charity Common Man Protection Force.',
#  '[32]']

# %%
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\saiva\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Konidela', 'NNP'), ('Pawan', 'NNP'), ('Kalyan', 'NNP'), ('[', 'VBD'), ('5', 'CD'), (']', 'NNP'), ('(', '('), ('born', 'VBN'), ('Konidela', 'NNP'), ('Kalyan', 'NNP'), ('Babu', 'NNP'), (';', ':'), ('[', 'VBZ'), ('8', 'CD'), (']', 'NN'), ('2', 'CD'), ('September', 'NNP'), ('1971', 'CD'), (')', ')'), ('[', 'VBD'), ('2', 'CD'), (']', 'JJ'), ('Indian', 'JJ'), ('politician', 'NN'), (',', ','), ('actor', 'NN'), (',', ','), ('philanthropist', 'NN'), (',', ','), ('martial', 'JJ'), ('artist', 'NN'), ('serving', 'VBG'), ('11th', 'CD'), ('Deputy', 'NNP'), ('Chief', 'NNP'), ('Minister', 'NNP'), ('Andhra', 'NNP'), ('Pradesh', 'NNP'), ('since', 'IN'), ('June', 'NNP'), ('2024', 'CD'), ('.', '.')]
# [('He', 'PRP'), ('also', 'RB'), ('Minister', 'NNP'), ('Panchayat', 'NNP'), ('Raj', 'NNP'), (',', ','), ('Rural', 'NNP'), ('Development', 'NNP'), ('Rural', 'NNP'), ('Water', 'NNP'), ('Supply', 'NNP'), (';', ':'), ('Environment', 'NNP'), (',', ','), ('Forest', 'NNP'), (',', ','), ('Science', 'NNP'), ('Technology', 'NNP'), ('Government', 'NNP'), ('Andhra', 'NNP'), ('Pradesh', 'NNP'), ('MLA', 'NNP'), ('representing', 'VBG'), ('Pithapuram', 'NNP'), ('constituency', 'NN'), ('.', '.')]
# [('[', 'RB'), ('3', 'CD'), (']', 'NN'), ('He', 'PRP'), ('founder', 'NN'), ('president', 'NN'), ('Janasena', 'NNP'), ('Party', 'NNP'), ('.', '.')]
# [('As', 'IN'), ('actor', 'NN'), (',', ','), ('Kalyan', 'NNP'), ('known', 'VBN'), ('distinctive', 'JJ'), ('style', 'NN'), ('mannerisms', 'NNS'), ('Telugu', 'NNP'), ('cinema', 'NN'), ('.', '.')]
# [('He', 'PRP'), ('enjoys', 'VBZ'), ('huge', 'JJ'), ('fanbase', 'NN'), ('across', 'IN'), ('Telugu', 'NNP'), ('states', 'NNS'), (',', ','), ('often', 'RB'), ('described', 'VBN'), ('``', '``'), ('unfathomable', 'JJ'), (',', ','), ("''", "''"), ('``', '``'), ('fiercely', 'RB'), ('loyal', 'JJ'), (',', ','), ("''", "''"), ('akin', 'IN'), ('``', '``'), ('cult', 'NN'), ('following', 'VBG'), ('.', '.')]
# [('``', '``'), ('[', '$'), ('12', 'CD'), (']', 'IN'), ('He', 'PRP'), ('among', 'IN'), ('highest-paid', 'JJ'), ('actors', 'NNS'), ('Indian', 'JJ'), ('cinema', 'NN'), ('featured', 'VBD'), ('Forbes', 'NNP'), ('India', 'NNP'), ("'s", 'POS'), ('Celebrity', 'NNP'), ('100', 'CD'), ('list', 'NN'), ('multiple', 'NN'), ('times', 'NNS'), ('since', 'IN'), ('2012', 'CD'), ('.', '.')]
# [('[', 'RB'), ('13', 'CD'), (']', 'JJ'), ('[', '$'), ('18', 'CD'), (']', 'NN'), ('He', 'PRP'), ('recipient', 'VBD'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('SIIMA', 'NNP'), ('Award', 'NNP'), ('among', 'IN'), ('accolades', 'NNS'), ('.', '.')]
# [('Kalyan', 'NNP'), ('made', 'VBD'), ('acting', 'VBG'), ('debut', 'NN'), ('1996', 'CD'), ('film', 'NN'), ('Akkada', 'NNP'), ('Ammayi', 'NNP'), ('Ikkada', 'NNP'), ('Abbayi', 'NNP'), ('.', '.')]
# [('Then', 'RB'), (',', ','), ('streak', 'VB'), ('six', 'CD'), ('consecutive', 'JJ'), ('hits', 'NNS'), (',', ','), ('among', 'IN'), ('Tholi', 'NNP'), ('Prema', 'NNP'), ('(', '('), ('1998', 'CD'), (')', ')'), (',', ','), ('Thammudu', 'NNP'), ('(', '('), ('1999', 'CD'), (')', ')'), (',', ','), ('Badri', 'NNP'), ('(', '('), ('2000', 'CD'), (')', ')'), (',', ','), ('Kushi', 'NNP'), ('(', '('), ('2001', 'CD'), (')', ')'), ('became', 'VBD'), ('back-to-back', 'JJ'), ('blockbusters', 'NNS'), ('.', '.')]
# [('These', 'DT'), ('films', 'NNS'), ('established', 'VBD'), ('Kalyan', 'NNP'), ('youth', 'NNP'), ('icon', 'JJ'), ('massive', 'JJ'), ('following', 'VBG'), ('distinct', 'JJ'), ('elder', 'FW'), ('brother', 'NN'), ('Chiranjeevi', 'NNP'), ("'s", 'POS'), ('fanbase', 'NN'), ('.', '.')]
# [('[', 'RB'), ('9', 'CD'), (']', 'JJ'), ('[', '$'), ('11', 'CD'), (']', 'NN'), ('In', 'IN'), ('2001', 'CD'), (',', ','), ('became', 'VBD'), ('first', 'JJ'), ('ever', 'RB'), ('South', 'NNP'), ('Indian', 'JJ'), ('brand', 'NN'), ('ambassador', 'NN'), ('Pepsi', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('22', 'CD'), (']', 'NNS'), ('Kalyan', 'NNP'), ('later', 'RB'), ('faced', 'VBD'), ('slump', 'NN'), (',', ','), ('yet', 'CC'), ('popularity', 'NN'), ('kept', 'VBD'), ('soaring', 'VBG'), ('despite', 'IN'), ('flops', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('24', 'CD'), (']', 'NN'), ('He', 'PRP'), ('made', 'VBD'), ('comeback', 'NN'), ('Jalsa', 'NNP'), ('(', '('), ('2008', 'CD'), (')', ')'), (',', ','), ('highest-grossing', 'JJ'), ('Telugu', 'NNP'), ('film', 'NN'), ('year', 'NN'), (',', ','), ('continued', 'VBD'), ('hits', 'NNS'), ('like', 'IN'), ('Gabbar', 'NNP'), ('Singh', 'NNP'), ('(', '('), ('2012', 'CD'), (')', ')'), (',', ','), ('Attarintiki', 'NNP'), ('Daredi', 'NNP'), ('(', '('), ('2013', 'CD'), (')', ')'), (',', ','), ('Gopala', 'NNP'), ('Gopala', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), (',', ','), ('Bheemla', 'NNP'), ('Nayak', 'NNP'), ('(', '('), ('2022', 'CD'), (')', ')'), ('.', '.')]
# [('He', 'PRP'), ('received', 'VBD'), ('Filmfare', 'NNP'), ('Award', 'NNP'), ('Best', 'NNP'), ('Actor', 'NNP'), ('Gabbar', 'NNP'), ('Singh', 'NNP'), ('.', '.')]
# [('Both', 'DT'), ('Kushi', 'NNP'), ('Attarintiki', 'NNP'), ('Daredi', 'NNP'), ('held', 'VBD'), ('record', 'JJ'), ('highest-grossing', 'NN'), ('Telugu', 'NNP'), ('film', 'NN'), ('era', 'NN'), ('.', '.')]
# [('[', 'RB'), ('25', 'CD'), (']', 'JJ'), ('Kalyan', 'NNP'), ('holds', 'VBZ'), ('black', 'JJ'), ('belt', 'NN'), ('Karate', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('26', 'CD'), (']', 'NNS'), ('In', 'IN'), ('1997', 'CD'), (',', ','), ('awarded', 'VBD'), ('title', 'NN'), ('``', '``'), ('Pawan', 'NNP'), ("''", "''"), ('Isshin-ryū', 'NNP'), ('Karate', 'NNP'), ('Association', 'NNP'), ('public', 'JJ'), ('martial', 'NN'), ('arts', 'NNS'), ('demonstration', 'NN'), ('.', '.')]
# [('[', 'RB'), ('27', 'CD'), (']', 'NN'), ('He', 'PRP'), ('practices', 'NNS'), ('various', 'JJ'), ('martial', 'JJ'), ('arts', 'NNS'), (',', ','), ('regularly', 'JJ'), ('showcases', 'NNS'), ('films', 'NNS'), ('performer', 'JJ'), ('action', 'NN'), ('choreographer', 'NN'), ('.', '.')]
# [('He', 'PRP'), ('known', 'VBZ'), ('``', '``'), ('Power', 'NNP'), ('Star', 'NNP'), ("''", "''"), ('among', 'IN'), ('fans', 'NNS'), ('media', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('28', 'CD'), (']', 'NNS'), ('Kalyan', 'NNP'), ('also', 'RB'), ('recognized', 'VBD'), ('extensive', 'JJ'), ('philanthropic', 'NN'), ('work', 'NN'), (',', ','), ('supporting', 'VBG'), ('various', 'JJ'), ('social', 'JJ'), ('causes', 'NNS'), ('.', '.')]
# [('[', 'RB'), ('29', 'CD'), (']', 'NN'), ('He', 'PRP'), ('offered', 'VBD'), ('financial', 'JJ'), ('assistance', 'NN'), ('individuals', 'NNS'), ('organizations', 'NNS'), ('need', 'VBP'), ('.', '.')]
# [('In', 'IN'), ('2007', 'CD'), (',', ','), ('established', 'VBN'), ('charity', 'NN'), ('Common', 'NNP'), ('Man', 'NNP'), ('Protection', 'NNP'), ('Force', 'NNP'), ('.', '.')]
# [('[', 'RB'), ('32', 'CD'), (']', 'NNS')]

# %%
print(nltk.pos_tag("Sun is bright!".split()))
# Out:
# [('Sun', 'NNP'), ('is', 'VBZ'), ('bright!', 'NN')]
